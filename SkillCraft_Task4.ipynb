# %% [markdown]
# # **Traffic Accident Data Analysis**

# %%
import pandas as pd
df = pd.read_csv('/content/output.csv')

# %%
df.info()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8010 entries, 0 to 8009
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Entity                 8010 non-null   object
#  1   Code                   6150 non-null   object
#  2   Year                   8010 non-null   int64
#  3   Deaths                 8010 non-null   int64
#  4   Sidedness              8010 non-null   int64
#  5   Historical_Population  6300 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 375.6+ KB
# Entity                    object
# Code                      object
# Year                       int64
# Deaths                     int64
# Sidedness                  int64
# Historical_Population    float64
# dtype: object

# %%
df.describe()
# Out:
#               Year        Deaths    Sidedness  Historical_Population
# count  8010.000000  8.010000e+03  8010.000000           6.300000e+03
# mean   2004.500000  4.451661e+04     0.213483           9.126228e+07
# std       8.655982  1.269077e+05     0.409791           5.435589e+08
# min    1990.000000  0.000000e+00     0.000000           1.126000e+03
# 25%    1997.000000  3.322500e+02     0.000000           1.219077e+06
# 50%    2004.500000  1.969500e+03     0.000000           6.502588e+06
# 75%    2012.000000  1.323600e+04     0.000000           2.302875e+07
# max    2019.000000  1.285039e+06     1.000000           7.713468e+09

# %%
df.head()
# Out:
#         Entity Code  Year  Deaths  Sidedness  Historical_Population
# 0  Afghanistan  AFG  1990    4154          0             12412311.0
# 1  Afghanistan  AFG  1991    4472          0             13299016.0
# 2  Afghanistan  AFG  1992    5106          0             14485543.0
# 3  Afghanistan  AFG  1993    5681          0             15816601.0
# 4  Afghanistan  AFG  1994    6001          0             17075728.0

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Deaths', 'Sidedness',
#        'Historical_Population'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# Entity                      0
# Code                     1860
# Year                        0
# Deaths                      0
# Sidedness                   0
# Historical_Population    1710
# dtype: int64

# %% [markdown]
# **Analyze Patterns Related to Road Conditions, Weather, and Time of Day**

# %%
# Plot deaths by year
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Deaths', data=df)
plt.title('Traffic Deaths Over the Years')
plt.xlabel('Year')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# **Visualize Accident Hotspots**

# %%
# Plot deaths by Entity (assuming it represents locations)
plt.figure(figsize=(12, 8))
sns.barplot(x='Entity', y='Deaths', data=df)
plt.title('Traffic Deaths by Location')
plt.xlabel('Location')
plt.ylabel('Deaths')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Identify Contributing Factors**

# %%
# Plot deaths by sidedness
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sidedness', y='Deaths', data=df)
plt.title('Traffic Deaths by Sidedness')
plt.xlabel('Sidedness')
plt.ylabel('Deaths')
plt.show()

# Plot deaths against historical population
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Historical_Population', y='Deaths', data=df)
plt.title('Traffic Deaths vs Historical Population')
plt.xlabel('Historical Population')
plt.ylabel('Deaths')
plt.show()
